# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import inspect
import psycopg2 as pc

# %%
csv = "C:/Users/16306/Downloads/cost of living 2020.csv"
costofliving_df = pd.read_csv(csv)
costofliving_df.head()
# Out:
#    rank       country  col_index  rent_index  col_rent_index  grocery_index  \
# 0     1      Bermuda      147.77       85.70          117.54         146.63
# 1     2  Switzerland      125.69       51.20           89.41         124.93
# 2     3       Norway       96.80       32.61           65.54          89.55
# 3     4      Iceland       90.19       38.54           65.04          80.91
# 4     5        Japan       86.22       26.18           56.98          86.84
#
#    rest_price_index  local_purchase_power_index  mcmeal
# 0            152.52                       78.17    0.00
# 1            118.55                      114.83   15.36
# 2             96.81                       83.40   12.36
# 3             97.17                       74.78   13.31
# 4             48.07                       78.88    6.70

# %%
new_costofliving_df = costofliving_df [['rank','country','col_index','rent_index','col_rent_index','grocery_index','rest_price_index','local_purchase_power_index','mcmeal']].copy()
new_costofliving_df
# Out:
#      rank       country  col_index  rent_index  col_rent_index  grocery_index  \
# 0       1      Bermuda      147.77       85.70          117.54         146.63
# 1       2  Switzerland      125.69       51.20           89.41         124.93
# 2       3       Norway       96.80       32.61           65.54          89.55
# 3       4      Iceland       90.19       38.54           65.04          80.91
# 4       5        Japan       86.22       26.18           56.98          86.84
# ..    ...           ...        ...         ...             ...            ...
# 130   131        Syria       27.04        5.77           16.68          24.42
# 131   132  Afghanistan       26.71        3.99           15.65          18.99
# 132   133   Kyrgyzstan       24.70        7.78           16.46          21.76
# 133   134        India       24.12        5.50           15.05          24.57
# 134   135     Pakistan       21.00        4.28           12.86          18.21
#
# ...

# %%
csv = "C:/Users/16306/Downloads/countries of the world.csv"
countries_df = pd.read_csv(csv)
countries_df.head()
# Out:
#            country                               region  population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    area_sq_mi pop_density coastline_ratio net_migration infant_mortality  \
# 0      647500        48,0            0,00         23,06           163,07
# 1       28748       124,6            1,26         -4,93            21,52
# 2     2381740        13,8            0,04         -0,39               31
# 3         199       290,4           58,29        -20,71             9,27
# 4         468       152,1            0,00           6,6             4,05
#
#        gdp literacy phones arable crops  other climate
# 0    700.0     36,0    3,2  12,13  0,22  87,65       1
# ...

# %%
new_countries_df = countries_df [['country','region','population','area_sq_mi','gdp']].copy()
new_countries_df
# Out:
#              country                               region  population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      area_sq_mi      gdp
# 0        647500    700.0
# 1         28748   4500.0
# 2       2381740   6000.0
# ...

# %%
rds_connection_string = "postgres:postgres@localhost:5432/bootcamp"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
costofliving_df.to_sql(name='cost_of_living',con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     902             xtras = self._psycopg2_extras()
# --> 903             context._psycopg2_fetched_rows = xtras.execute_values(
#     904                 cursor,
#
# ~\anaconda3\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1291         parts[-1:] = post
# ...

# %%
new_countries_df.to_sql(name='countries',con=engine, if_exists='append', index=False)
